# %%
import pandas as pd

# %%
lab_output = pd.read_csv('/media/data/huyennm/mimic-iv/notebook/lab/lab_results/lab_output.csv')
lab_output
# Out:
#        subject_id   stay_id  hematocrit_min  hematocrit_max  hemoglobin_min  \
# 0        13180007  30000213            23.9            27.6             7.4
# 1        18421337  30000484            24.6            31.0             8.1
# 2        15726459  30000831            38.0            40.8            12.4
# 3        12168737  30001336            24.3            26.4             8.2
# 4        14311522  30002548            35.2            39.7            11.6
# ...           ...       ...             ...             ...             ...
# 25777    19046950  39998622            40.5            45.9            13.3
# 25778    15954569  39998871            24.1            26.0             7.0
# 25779    19425920  39999168            26.5            27.6             7.9
# 25780    15669140  39999172            18.9            23.1             6.1
# 25781    15498623  39999384            23.4            24.8             7.7
#
# ...

# %%
len(lab_output.columns)
# Out:
# 46

# %%
missing_percentage = (lab_output.isna().sum() / len(lab_output)) * 100
missing_percentage
# Out:
# subject_id          0.000000
# stay_id             0.000000
# hematocrit_min      0.694283
# hematocrit_max      0.694283
# hemoglobin_min      0.733070
# hemoglobin_max      0.733070
# platelets_min       0.752463
# platelets_max       0.752463
# wbc_min             0.756342
# wbc_max             0.756342
# rbc_min             0.767978
# rbc_max             0.767978
# creatinine_min      0.581801
# creatinine_max      0.581801
# bun_min             0.597316
# bun_max             0.597316
# lactate_min       100.000000
# lactate_max       100.000000
# glucose_min         0.872702
# glucose_max         0.872702
# sodium_min          0.643860
# sodium_max          0.643860
# potassium_min       0.659375
# potassium_max       0.659375
# calcium_min         5.542627
# calcium_max         5.542627
# magnesium_min       2.525017
# magnesium_max       2.525017
# chloride_min        0.624467
# chloride_max        0.624467
# inr_min             8.269335
# inr_max             8.269335
# ...
