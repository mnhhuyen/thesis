# %%
import pandas as pd
import pandasql as psql

# %%
file_event_path = '/media/data3/biodataset/MIMIC_IV/MIMIC-IV-v2.2/physionet.org/files/mimiciv/2.2/icu/d_items.csv'

chunksize = 10**6
chunk_list = []

for chunk in pd.read_csv(file_event_path, chunksize=chunksize):
    chunk_list.append(chunk)
event_df = pd.concat(chunk_list, axis=0)
event_df
# Out:
#       itemid                             label  \
# 0     220001                      Problem List
# 1     220003                ICU Admission date
# 2     220045                        Heart Rate
# 3     220046           Heart rate Alarm - High
# 4     220047            Heart Rate Alarm - Low
# ...      ...                               ...
# 4009  230077   Documented on DC Summary (PICC)
# 4010  230078  Documented on DC Summary (Thora)
# 4011  230083    Replacement Fluid (Pre-Filter)
# 4012  230084   Replacement Fluid (Post-Filter)
# 4013  230085                   Dialysate Fluid
#
#                           abbreviation         linksto             category  \
# 0                         Problem List     chartevents              General
# 1                   ICU Admission date  datetimeevents                  ADT
# 2                                   HR     chartevents  Routine Vital Signs
# 3                      HR Alarm - High     chartevents               Alarms
# ...

# %%
df = event_df[event_df['label'].str.contains('gcs', case=False)]
df
# Out:
#       itemid                               label  \
# 159   220739                   GCS - Eye Opening
# 407   223900               GCS - Verbal Response
# 408   223901                GCS - Motor Response
# 1965  226755                    GcsApacheIIScore
# 1966  226756                 GCSEyeApacheIIValue
# 1967  226757               GCSMotorApacheIIValue
# 1968  226758              GCSVerbalApacheIIValue
# 2054  227011                     GCSEye_ApacheIV
# 2055  227012                   GCSMotor_ApacheIV
# 2056  227013                   GcsScore_ApacheIV
# 2057  227014                  GCSVerbal_ApacheIV
# 2660  228112  GCSVerbalApacheIIValue (intubated)
#
#                             abbreviation      linksto                category  \
# 159                          Eye Opening  chartevents            Neurological
# 407                      Verbal Response  chartevents            Neurological
# 408                       Motor Response  chartevents            Neurological
# ...

# %%
item_ids = df['itemid'].unique()
item_ids = ([220739, 223900, 223901])
item_ids
# Out:
# [220739, 223900, 223901]

# %% [markdown]
# height

# %%
chartevents_path = '/media/data3/biodataset/MIMIC_IV/MIMIC-IV-v2.2/physionet.org/files/mimiciv/2.2/icu/chartevents.csv'
chartevents_df = pd.read_csv(chartevents_path, chunksize=10**6)
filtered_chartevents_list = []

for chunk in chartevents_df:
    filtered_chunk = chunk[chunk['stay_id'] == 38848838] 
    filtered_chartevents_list.append(filtered_chunk)
    
filtered_chartevents_df = pd.concat(filtered_chartevents_list, axis=0)
filtered_chartevents_df
# Out:
#           subject_id   hadm_id   stay_id  caregiver_id            charttime  \
# 15289932    10509305  27629385  38848838       47023.0  2171-04-09 10:53:00
# 15289933    10509305  27629385  38848838       47023.0  2171-04-09 10:53:00
# 15289934    10509305  27629385  38848838       47023.0  2171-04-09 10:53:00
# 15289935    10509305  27629385  38848838       47023.0  2171-04-09 10:53:00
# 15289936    10509305  27629385  38848838       47023.0  2171-04-09 12:00:00
# ...              ...       ...       ...           ...                  ...
# 15290078    10509305  27629385  38848838           NaN  2171-04-09 13:12:00
# 15290079    10509305  27629385  38848838           NaN  2171-04-09 13:12:00
# 15290080    10509305  27629385  38848838           NaN  2171-04-09 13:12:00
# 15290081    10509305  27629385  38848838           NaN  2171-04-09 13:12:00
# 15290082    10509305  27629385  38848838           NaN  2171-04-09 13:12:00
#
# ...

# %%
filtered_chartevents_df[filtered_chartevents_df['itemid'] == 220739]
# Out:
# Empty DataFrame
# Columns: [subject_id, hadm_id, stay_id, caregiver_id, charttime, storetime, itemid, value, valuenum, valueuom, warning]
# Index: []

# %%
filtered_chartevents_df[filtered_chartevents_df['itemid'] == 226707]
# Out:
#        subject_id   hadm_id   stay_id  caregiver_id            charttime  \
# 40604    10002428  20321825  34807493       62692.0  2156-04-30 20:36:00
# 57042    10002428  28662225  33987268        8549.0  2156-04-12 16:24:00
#
#                  storetime  itemid value  valuenum valueuom  warning
# 40604  2156-05-02 16:37:00  226707    59      59.0     Inch      0.0
# 57042  2156-04-15 15:03:00  226707    59      59.0     Inch      0.0

# %%
test = pd.read_csv('/media/data/huyennm/mimic-iv/mimic-derived/gcs.csv')
# Out:
# array([220739, 223900, 223901, 226755, 226756, 226757, 226758, 227013])

# %%
filtered_chartevents_df.to_csv('/media/data/huyennm/mimic-iv/mimic-derived/height.csv', index=False)
